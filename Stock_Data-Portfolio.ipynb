# %%
import os, glob
import pandas as pd
from arch import arch_model
from arch.__future__ import reindexing
import math
import numpy as np
import matplotlib.pyplot as plt

path = "/home/srijan/Documents/NIFTY/NIFTY 50/"

all_files = glob.glob(os.path.join(path, "data*.csv"))
df_from_each_file = (pd.read_csv(f, sep=',') for f in all_files)
df_merged_NIFTY50   = pd.concat(df_from_each_file, ignore_index=True)
df_merged_NIFTY50.to_csv( "merged.csv")

# %%
df_merged_NIFTY50['Date'] = pd.to_datetime(df_merged_NIFTY50['Date'])
df_merged_NIFTY50 = df_merged_NIFTY50.sort_values(by="Date")
df_merged_NIFTY50
# Out:
#            Date     Open     High      Low    Close  Shares Traded  \
# 3237 2000-04-03  1528.70  1555.50  1510.75  1534.75       50909584
# 3238 2000-04-04  1534.05  1534.05  1420.85  1428.10       42180348
# 3239 2000-04-05  1428.50  1467.40  1391.65  1434.65       49400946
# 3240 2000-04-06  1436.15  1475.25  1381.05  1452.95       40869843
# 3241 2000-04-07  1453.30  1558.05  1453.30  1557.15       49468064
# ...         ...      ...      ...      ...      ...            ...
# 4968 2020-03-20  8284.45  8883.00  8178.20  8745.45     1072263600
# 4969 2020-03-23  7945.70  8159.25  7583.60  7610.25      654151814
# 4970 2020-03-24  7848.30  8036.95  7511.10  7801.05      739354439
# 4971 2020-03-25  7735.15  8376.75  7714.75  8317.85      738114713
# 4972 2020-03-26  8451.00  8749.05  8304.90  8641.45      866534643
#
#       Turnover (Rs. Cr)
# 3237            1638.46
# 3238            1071.07
# 3239            1880.26
# 3240            1850.96
# 3241            1272.20
# ...

# %%
path = "/home/srijan/Documents/NIFTY/NIFTY 500/"

all_files = glob.glob(os.path.join(path, "data*.csv"))
df_from_each_file = (pd.read_csv(f, sep=',') for f in all_files)
df_merged_NIFTY500  = pd.concat(df_from_each_file, ignore_index=True)
df_merged_NIFTY500.to_csv( "merged.csv")
df_merged_NIFTY500['Date'] = pd.to_datetime(df_merged_NIFTY500['Date'])
df_merged_NIFTY500 = df_merged_NIFTY500.sort_values(by="Date")
df_merged_NIFTY500
# Out:
#            Date     Open     High      Low    Close    Shares Traded  \
# 3237 2000-04-03  1322.95  1337.95  1283.55  1287.99         69179064
# 3238 2000-04-04  1287.80  1287.80  1193.20  1197.20         58745239
# 3239 2000-04-05  1196.70  1224.75  1154.65  1194.90         63837485
# 3240 2000-04-06  1195.15  1225.10  1134.55  1205.35         61330829
# 3241 2000-04-07  1205.55  1284.95  1205.55  1284.80         59503476
# ...         ...      ...      ...      ...      ...              ...
# 4968 2020-03-20  6833.65  7267.25  6744.80  7160.10       2868975659
# 4969 2020-03-23  6522.80  6692.85  6226.10  6243.00       1654280663
# 4970 2020-03-24  6421.00  6556.65  6151.60  6365.45       1822797341
# 4971 2020-03-25  6299.75  6758.75  6291.85  6724.00       1609584079
# 4972 2020-03-26  6826.05  7079.75  6722.35  6993.85       2058864707
#
#      Turnover (Rs. Cr)
# 3237           2734.45
# 3238           1227.95
# 3239           2510.88
# 3240           3119.09
# ...

# %%
path = "/home/srijan/Documents/NIFTY/NIFTY BANK/"

all_files = glob.glob(os.path.join(path, "data*.csv"))
df_from_each_file = (pd.read_csv(f, sep=',') for f in all_files)
df_merged_NIFTYBANK  = pd.concat(df_from_each_file, ignore_index=True)
df_merged_NIFTYBANK.to_csv( "merged.csv")
df_merged_NIFTYBANK['Date'] = pd.to_datetime(df_merged_NIFTYBANK['Date'])
df_merged_NIFTYBANK = df_merged_NIFTYBANK.sort_values(by="Date")
df_merged_NIFTYBANK
# Out:
#            Date      Open      High       Low     Close    Shares Traded  \
# 3237 2000-04-03         -         -         -   1110.14                -
# 3238 2000-04-04         -         -         -   1026.65                -
# 3239 2000-04-05         -         -         -   1000.84                -
# 3240 2000-04-06         -         -         -    989.20                -
# 3241 2000-04-07         -         -         -   1048.75                -
# ...         ...       ...       ...       ...       ...              ...
# 4968 2020-03-20   19898.3  20924.55   19265.0  20317.60        501768418
# 4969 2020-03-23   18311.3  18895.65  16791.05  16917.65        307639369
# 4970 2020-03-24  17705.85   17841.4  16116.25  17107.30        391702593
# 4971 2020-03-25  16759.95   18740.2   16635.5  18481.05        394556026
# 4972 2020-03-26  18781.85  20409.35   18364.5  19613.90        482884243
#
#      Turnover (Rs. Cr)
# 3237                 -
# 3238                 -
# ...

# %%
path = "/home/srijan/Documents/NIFTY/NIFTY FMCG/"

all_files = glob.glob(os.path.join(path, "data*.csv"))
df_from_each_file = (pd.read_csv(f, sep=',') for f in all_files)
df_merged_NIFTYFMCG  = pd.concat(df_from_each_file, ignore_index=True)
df_merged_NIFTYFMCG.to_csv( "merged.csv")
df_merged_NIFTYFMCG['Date'] = pd.to_datetime(df_merged_NIFTYFMCG['Date'])
df_merged_NIFTYFMCG = df_merged_NIFTYFMCG.sort_values(by="Date")
df_merged_NIFTYFMCG
# Out:
#            Date      Open      High       Low     Close    Shares Traded  \
# 3237 2000-04-03         -         -         -   3116.48                -
# 3238 2000-04-04         -         -         -   2905.45                -
# 3239 2000-04-05         -         -         -   2962.45                -
# 3240 2000-04-06         -         -         -   2954.22                -
# 3241 2000-04-07         -         -         -   3155.47                -
# ...         ...       ...       ...       ...       ...              ...
# 4968 2020-03-20   24198.2   26113.7   24198.2  25931.60         87762108
# 4969 2020-03-23  23950.55  24373.55   23082.2  23184.05         69667235
# 4970 2020-03-24   24123.3  24584.85  23390.45  23935.30         83206249
# 4971 2020-03-25  23804.85  24695.25   23646.7  24471.70         92962761
# 4972 2020-03-26  24727.15  26091.05   24295.6  25680.10         87681348
#
#      Turnover (Rs. Cr)
# 3237                 -
# 3238                 -
# ...

# %%
path = "/home/srijan/Documents/NIFTY/NIFTY IT/"

all_files = glob.glob(os.path.join(path, "data*.csv"))
df_from_each_file = (pd.read_csv(f, sep=',') for f in all_files)
df_merged_NIFTYIT  = pd.concat(df_from_each_file, ignore_index=True)
df_merged_NIFTYIT.to_csv( "merged.csv")
df_merged_NIFTYIT['Date'] = pd.to_datetime(df_merged_NIFTYIT['Date'])
df_merged_NIFTYIT = df_merged_NIFTYIT.sort_values(by="Date")
df_merged_NIFTYIT
# Out:
#            Date      Open      High       Low     Close    Shares Traded  \
# 3237 2000-04-03      0.00      0.00      0.00  59926.91          5378362
# 3238 2000-04-04      0.00      0.00      0.00  55134.36           494780
# 3239 2000-04-05      0.00      0.00      0.00  55011.28          6724624
# 3240 2000-04-06      0.00      0.00      0.00  56163.42         12260874
# 3241 2000-04-07      0.00      0.00      0.00  60041.69          1311800
# ...         ...       ...       ...       ...       ...              ...
# 4968 2020-03-20  11382.40  12710.55  11363.50  12363.40         66433629
# 4969 2020-03-23  11328.25  11602.45  11108.65  11179.60         44666228
# 4970 2020-03-24  11159.75  12053.80  11159.30  11865.05         51315528
# 4971 2020-03-25  11856.90  12514.25  11657.25  12233.35         47599771
# 4972 2020-03-26  12496.95  12751.55  12306.35  12535.60         47125315
#
#      Turnover (Rs. Cr)
# 3237            778.22
# 3238             52.41
# ...

# %%
path = "/home/srijan/Documents/NIFTY/NIFTY Pharma/"

all_files = glob.glob(os.path.join(path, "data*.csv"))
df_from_each_file = (pd.read_csv(f, sep=',') for f in all_files)
df_merged_NIFTYPharma  = pd.concat(df_from_each_file, ignore_index=True)
df_merged_NIFTYPharma.to_csv( "merged.csv")
df_merged_NIFTYPharma['Date'] = pd.to_datetime(df_merged_NIFTYPharma['Date'])
df_merged_NIFTYPharma = df_merged_NIFTYPharma.sort_values(by="Date")
df_merged_NIFTYPharma
# Out:
#            Date     Open     High      Low    Close    Shares Traded  \
# 3237 2001-01-01        -        -        -  1000.00                -
# 3238 2001-01-02        -        -        -   973.10                -
# 3239 2001-01-03        -        -        -   974.49                -
# 3240 2001-01-04        -        -        -   966.84                -
# 3241 2001-01-05        -        -        -   986.32                -
# ...         ...      ...      ...      ...      ...              ...
# 4780 2020-03-20  6740.25  7088.15  6728.75  6951.90         50098202
# 4781 2020-03-23   6518.0  6850.55   6380.1  6432.30         33278043
# 4782 2020-03-24  6589.45   6828.3  6532.65  6611.05         34381735
# 4783 2020-03-25   6539.6   6746.3  6538.55  6695.55         30766064
# 4784 2020-03-26  6845.25  6963.25  6743.05  6775.00         43517854
#
#      Turnover (Rs. Cr)
# 3237                 -
# 3238                 -
# 3239                 -
# 3240                 -
# ...

# %%
path = "/home/srijan/Documents/NIFTY/NIFTY Realty/"

all_files = glob.glob(os.path.join(path, "data*.csv"))
df_from_each_file = (pd.read_csv(f, sep=',') for f in all_files)
df_merged_NIFTYRealty  = pd.concat(df_from_each_file, ignore_index=True)
df_merged_NIFTYRealty.to_csv( "merged.csv")
df_merged_NIFTYRealty['Date'] = pd.to_datetime(df_merged_NIFTYRealty['Date'])
df_merged_NIFTYRealty = df_merged_NIFTYRealty.sort_values(by="Date")
df_merged_NIFTYRealty
# Out:
#            Date    Open    High     Low   Close    Shares Traded  \
# 1986 2007-04-02       -       -       -  717.62          2681579
# 1987 2007-04-03       -       -       -  693.98          3627739
# 1988 2007-04-04       -       -       -  684.05          3708949
# 1989 2007-04-05       -       -       -  687.89          5336533
# 1990 2007-04-09       -       -       -  718.71          5080245
# ...         ...     ...     ...     ...     ...              ...
# 241  2020-03-23  178.55  185.35   171.1  174.10          9352131
# 242  2020-03-24  175.55   181.6  166.15  170.65         15191738
# 243  2020-03-25   166.5   176.4  165.35  175.10         17108422
# 244  2020-03-26  177.75   189.7   173.0  185.80         22629440
# 245  2020-03-27   191.9  199.45  181.65  185.05         19297142
#
#      Turnover (Rs. Cr)
# 1986            105.66
# 1987             142.9
# 1988            137.72
# 1989            210.04
# 1990            213.25
# ...                ...
# ...

# %%
path = "/home/srijan/Documents/NIFTY/NIFTY Auto/"

all_files = glob.glob(os.path.join(path, "data*.csv"))
df_from_each_file = (pd.read_csv(f, sep=',') for f in all_files)
df_merged_NIFTYAuto  = pd.concat(df_from_each_file, ignore_index=True)
df_merged_NIFTYAuto.to_csv( "merged.csv")
df_merged_NIFTYAuto['Date'] = pd.to_datetime(df_merged_NIFTYAuto['Date'])
df_merged_NIFTYAuto = df_merged_NIFTYAuto.sort_values(by="Date")
df_merged_NIFTYAuto
# Out:
#            Date     Open     High      Low    Close    Shares Traded  \
# 3469 2004-03-31        -        -        -  1005.92                -
# 3470 2004-04-01        -        -        -  1030.55                -
# 3471 2004-04-02        -        -        -  1032.65                -
# 3472 2004-04-05        -        -        -  1047.45                -
# 3473 2004-04-06        -        -        -  1036.69                -
# ...         ...      ...      ...      ...      ...              ...
# 733  2020-03-20   5230.2   5423.2   5154.1  5370.15        229830607
# 734  2020-03-23  4908.15  5013.85  4593.05  4626.50        120637088
# 735  2020-03-24   4726.4  4850.85   4452.2  4693.35        146706064
# 736  2020-03-25  4600.05   5001.9  4577.15  4936.15        147442630
# 737  2020-03-26   4981.9   5163.7  4847.15  5061.30        208806955
#
#      Turnover (Rs. Cr)
# 3469                 -
# 3470                 -
# 3471                 -
# 3472                 -
# ...

# %%
path = "/home/srijan/Documents/NIFTY/NIFTY FS/"

all_files = glob.glob(os.path.join(path, "data*.csv"))
df_from_each_file = (pd.read_csv(f, sep=',') for f in all_files)
df_merged_NIFTYFS  = pd.concat(df_from_each_file, ignore_index=True)
df_merged_NIFTYFS.to_csv( "merged.csv")
df_merged_NIFTYFS['Date'] = pd.to_datetime(df_merged_NIFTYFS['Date'])
df_merged_NIFTYFS = df_merged_NIFTYFS.sort_values(by="Date")
df_merged_NIFTYFS
# Out:
#            Date     Open      High      Low    Close    Shares Traded  \
# 3469 2004-03-31        -         -        -  1040.82                -
# 3470 2004-04-01        -         -        -  1063.98                -
# 3471 2004-04-02        -         -        -  1078.00                -
# 3472 2004-04-05        -         -        -  1066.30                -
# 3473 2004-04-06        -         -        -  1069.62                -
# ...         ...      ...       ...      ...      ...              ...
# 733  2020-03-20  9539.95   10113.3   9175.8  9871.95        454848867
# 734  2020-03-23   8898.4    9210.2  8239.15  8298.50        273309987
# 735  2020-03-24   8623.0    8746.7   7984.2  8418.70        303850237
# 736  2020-03-25  8285.25   9247.85  8256.45  9203.30        294945987
# 737  2020-03-26  9366.95  10073.85  9174.25  9698.55        394293210
#
#      Turnover (Rs. Cr)
# 3469                 -
# 3470                 -
# 3471                 -
# 3472                 -
# ...

# %%
path = "/home/srijan/Documents/NIFTY/NIFTY Health/"

all_files = glob.glob(os.path.join(path, "data*.csv"))
df_from_each_file = (pd.read_csv(f, sep=',') for f in all_files)
df_merged_NIFTYHealth  = pd.concat(df_from_each_file, ignore_index=True)
df_merged_NIFTYHealth.to_csv( "merged.csv")
df_merged_NIFTYHealth['Date'] = pd.to_datetime(df_merged_NIFTYHealth['Date'])
df_merged_NIFTYHealth = df_merged_NIFTYHealth.sort_values(by="Date")
df_merged_NIFTYHealth
# Out:
#            Date Open High Low    Close Shares Traded Turnover (Rs. Cr)
# 2220 2005-04-01    -    -   -  1000.00             -                 -
# 2221 2005-04-04    -    -   -  1011.35             -                 -
# 2222 2005-04-05    -    -   -   998.85             -                 -
# 2223 2005-04-06    -    -   -   998.86             -                 -
# 2224 2005-04-07    -    -   -   991.10             -                 -
# ...         ...  ...  ...  ..      ...           ...               ...
# 3713 2020-03-23    -    -   -  4018.85             -                 -
# 3714 2020-03-24    -    -   -  4107.06             -                 -
# 3715 2020-03-25    -    -   -  4152.13             -                 -
# 3716 2020-03-26    -    -   -  4201.71             -                 -
# 3717 2020-03-27    -    -   -  4209.01             -                 -
#
# [3718 rows x 7 columns]

# %%
path = "/home/srijan/Documents/NIFTY/NIFTY Media/"

all_files = glob.glob(os.path.join(path, "data*.csv"))
df_from_each_file = (pd.read_csv(f, sep=',') for f in all_files)
df_merged_NIFTYMedia  = pd.concat(df_from_each_file, ignore_index=True)
df_merged_NIFTYMedia.to_csv( "merged.csv")
df_merged_NIFTYMedia['Date'] = pd.to_datetime(df_merged_NIFTYMedia['Date'])
df_merged_NIFTYMedia = df_merged_NIFTYMedia.sort_values(by="Date")
df_merged_NIFTYMedia
# Out:
#            Date     Open     High      Low    Close    Shares Traded  \
# 2972 2006-04-03        -        -        -  1379.10                -
# 2973 2006-04-04        -        -        -  1403.89                -
# 2974 2006-04-05        -        -        -  1406.02                -
# 2975 2006-04-07        -        -        -  1396.43                -
# 2976 2006-04-10        -        -        -  1383.35                -
# ...         ...      ...      ...      ...      ...              ...
# 3462 2020-03-23  1038.45   1088.0  1001.35  1015.40         16780168
# 3463 2020-03-24  1030.35   1050.5   979.05  1031.70         28502138
# 3464 2020-03-25  1013.25  1066.85   989.85  1055.45         21556522
# 3465 2020-03-26   1065.7  1114.05   1048.3  1067.50         24239092
# 3466 2020-03-27   1086.2  1120.05  1049.55  1055.40         23005921
#
#      Turnover (Rs. Cr)
# 2972                 -
# 2973                 -
# 2974                 -
# 2975                 -
# ...

# %%
path = "/home/srijan/Documents/NIFTY/NIFTY PSUB/"

all_files = glob.glob(os.path.join(path, "data*.csv"))
df_from_each_file = (pd.read_csv(f, sep=',') for f in all_files)
df_merged_NIFTYPSUB = pd.concat(df_from_each_file, ignore_index=True)
df_merged_NIFTYPSUB.to_csv( "merged.csv")
df_merged_NIFTYPSUB['Date'] = pd.to_datetime(df_merged_NIFTYPSUB['Date'])
df_merged_NIFTYPSUB = df_merged_NIFTYPSUB.sort_values(by="Date")
df_merged_NIFTYPSUB
# Out:
#            Date     Open     High      Low    Close    Shares Traded  \
# 3458 2004-03-31        -        -        -  1135.52                -
# 3459 2004-04-01        -        -        -  1160.99                -
# 3460 2004-04-02        -        -        -  1180.17                -
# 3461 2004-04-05        -        -        -  1169.73                -
# 3462 2004-04-06        -        -        -  1183.90                -
# ...         ...      ...      ...      ...      ...              ...
# 733  2020-03-20   1452.6  1514.05  1434.75  1463.45        177163535
# 734  2020-03-23  1349.85   1379.1  1270.95  1277.75        113161952
# 735  2020-03-24   1326.6   1342.8   1243.7  1305.35        133761216
# 736  2020-03-25   1271.3   1361.1  1254.85  1327.55        136462943
# 737  2020-03-26   1342.1   1398.9   1305.0  1335.15        188318325
#
#      Turnover (Rs. Cr)
# 3458                 -
# 3459                 -
# 3460                 -
# 3461                 -
# ...

# %%
path = "/home/srijan/Documents/NIFTY/NIFTY PubB/"

all_files = glob.glob(os.path.join(path, "data*.csv"))
df_from_each_file = (pd.read_csv(f, sep=',') for f in all_files)
df_merged_NIFTYPubB = pd.concat(df_from_each_file, ignore_index=True)
df_merged_NIFTYPubB.to_csv( "merged.csv")
df_merged_NIFTYPubB['Date'] = pd.to_datetime(df_merged_NIFTYPubB['Date'])
df_merged_NIFTYPubB = df_merged_NIFTYPubB.sort_values(by="Date")
df_merged_NIFTYPubB
# Out:
#            Date      Open      High      Low     Close    Shares Traded  \
# 2220 2005-04-01         -         -        -   1000.00                -
# 2221 2005-04-04         -         -        -   1004.92                -
# 2222 2005-04-05         -         -        -   1003.12                -
# 2223 2005-04-06         -         -        -   1009.06                -
# 2224 2005-04-07         -         -        -   1006.74                -
# ...         ...       ...       ...      ...       ...              ...
# 3713 2020-03-23   9859.85  10104.35  8906.05   8974.30        211859039
# 3714 2020-03-24   9400.05    9478.5  8487.25   9050.50        279625553
# 3715 2020-03-25    8852.3    9906.7   8794.9   9775.85        274667755
# 3716 2020-03-26    9959.1   10990.0   9779.6  10556.20        317203372
# 3717 2020-03-27  11241.15  11586.75  10505.1  10738.15        357598614
#
#      Turnover (Rs. Cr)
# 2220                 -
# 2221                 -
# 2222                 -
# ...

# %%
path = "/home/srijan/Documents/NIFTY/NIFTY Gsec/"

all_files = glob.glob(os.path.join(path, "data*.csv"))
df_from_each_file = (pd.read_csv(f, sep=',') for f in all_files)
df_merged_NIFTYGsec = pd.concat(df_from_each_file, ignore_index=True)
df_merged_NIFTYGsec.to_csv( "merged.csv")
df_merged_NIFTYGsec['Date'] = pd.to_datetime(df_merged_NIFTYGsec['Date'])
df_merged_NIFTYGsec = df_merged_NIFTYGsec.sort_values(by="Date")
df_merged_NIFTYGsec
# Out:
#            Date     Open     High      Low    Close Shares Traded  \
# 1946 2011-01-03        -        -        -  1000.00             -
# 1947 2011-01-04        -        -        -   999.07             -
# 1948 2011-01-05        -        -        -   999.79             -
# 1949 2011-01-06        -        -        -   995.69             -
# 1950 2011-01-07        -        -        -   992.69             -
# ...         ...      ...      ...      ...      ...           ...
# 1941 2021-05-31  2315.91  2315.91  2311.18  2311.32             -
# 1942 2021-06-01   2311.7  2311.72  2310.53  2310.67             -
# 1943 2021-06-02  2311.05  2312.86  2311.05  2312.67             -
# 1944 2021-06-03  2313.05  2314.27   2312.6  2314.38             -
# 1945 2021-06-04  2314.76  2316.45  2311.85  2312.51             -
#
#      Turnover (Rs. Cr)
# 1946                 -
# 1947                 -
# 1948                 -
# 1949                 -
# 1950                 -
# ...                ...
# ...

# %%
df_merged_NIFTY50.set_index('Date', inplace=True)
NewNIFTY50 = df_merged_NIFTY50[['Close']]
NewNIFTY50
# Out:
#               Close
# Date
# 2000-04-03  1534.75
# 2000-04-04  1428.10
# 2000-04-05  1434.65
# 2000-04-06  1452.95
# 2000-04-07  1557.15
# ...             ...
# 2020-03-20  8745.45
# 2020-03-23  7610.25
# 2020-03-24  7801.05
# 2020-03-25  8317.85
# 2020-03-26  8641.45
#
# [4973 rows x 1 columns]

# %%
NewNIFTY50 = NewNIFTY50.rename(columns={"Close":"Nifty50"})
NewNIFTY50
# Out:
#             Nifty50
# Date
# 2000-04-03  1534.75
# 2000-04-04  1428.10
# 2000-04-05  1434.65
# 2000-04-06  1452.95
# 2000-04-07  1557.15
# ...             ...
# 2020-03-20  8745.45
# 2020-03-23  7610.25
# 2020-03-24  7801.05
# 2020-03-25  8317.85
# 2020-03-26  8641.45
#
# [4973 rows x 1 columns]

# %%
df_merged_NIFTY500.set_index('Date', inplace=True)
NewNIFTY500 = df_merged_NIFTY500[['Close']]
NewNIFTY500 = NewNIFTY500.rename(columns={"Close":"Nifty500"})
NewNIFTY500
# Out:
#             Nifty500
# Date
# 2000-04-03   1287.99
# 2000-04-04   1197.20
# 2000-04-05   1194.90
# 2000-04-06   1205.35
# 2000-04-07   1284.80
# ...              ...
# 2020-03-20   7160.10
# 2020-03-23   6243.00
# 2020-03-24   6365.45
# 2020-03-25   6724.00
# 2020-03-26   6993.85
#
# [4973 rows x 1 columns]

# %%
df_merged_NIFTYBANK.set_index('Date', inplace=True)
NewNIFTYBANK = df_merged_NIFTYBANK[['Close']]
NewNIFTYBANK = NewNIFTYBANK.rename(columns={"Close":"NiftyBANK"})
NewNIFTYBANK
# Out:
#             NiftyBANK
# Date
# 2000-04-03    1110.14
# 2000-04-04    1026.65
# 2000-04-05    1000.84
# 2000-04-06     989.20
# 2000-04-07    1048.75
# ...               ...
# 2020-03-20   20317.60
# 2020-03-23   16917.65
# 2020-03-24   17107.30
# 2020-03-25   18481.05
# 2020-03-26   19613.90
#
# [4973 rows x 1 columns]

# %%
df_merged_NIFTYFMCG.set_index('Date', inplace=True)
NewNIFTYFMCG = df_merged_NIFTYFMCG[['Close']]
NewNIFTYFMCG = NewNIFTYFMCG.rename(columns={"Close":"NiftyFMCG"})
NewNIFTYFMCG
# Out:
#             NiftyFMCG
# Date
# 2000-04-03    3116.48
# 2000-04-04    2905.45
# 2000-04-05    2962.45
# 2000-04-06    2954.22
# 2000-04-07    3155.47
# ...               ...
# 2020-03-20   25931.60
# 2020-03-23   23184.05
# 2020-03-24   23935.30
# 2020-03-25   24471.70
# 2020-03-26   25680.10
#
# [4973 rows x 1 columns]

# %%
df_merged_NIFTYIT.set_index('Date', inplace=True)
NewNIFTYIT = df_merged_NIFTYIT[['Close']]
NewNIFTYIT = NewNIFTYIT.rename(columns={"Close":"NiftyIT"})
NewNIFTYIT
# Out:
#              NiftyIT
# Date
# 2000-04-03  59926.91
# 2000-04-04  55134.36
# 2000-04-05  55011.28
# 2000-04-06  56163.42
# 2000-04-07  60041.69
# ...              ...
# 2020-03-20  12363.40
# 2020-03-23  11179.60
# 2020-03-24  11865.05
# 2020-03-25  12233.35
# 2020-03-26  12535.60
#
# [4973 rows x 1 columns]

# %%
df_merged_NIFTYPharma.set_index('Date', inplace=True)
NewNIFTYPharma = df_merged_NIFTYPharma[['Close']]
NewNIFTYPharma = NewNIFTYPharma.rename(columns={"Close":"NiftyPharma"})
NewNIFTYPharma
# Out:
#             NiftyPharma
# Date
# 2001-01-01      1000.00
# 2001-01-02       973.10
# 2001-01-03       974.49
# 2001-01-04       966.84
# 2001-01-05       986.32
# ...                 ...
# 2020-03-20      6951.90
# 2020-03-23      6432.30
# 2020-03-24      6611.05
# 2020-03-25      6695.55
# 2020-03-26      6775.00
#
# [4785 rows x 1 columns]

# %%
df_merged_NIFTYRealty.set_index('Date', inplace=True)
NewNIFTYRealty = df_merged_NIFTYRealty[['Close']]
NewNIFTYRealty = NewNIFTYRealty.rename(columns={"Close":"NiftyRealty"})
NewNIFTYRealty
# Out:
#             NiftyRealty
# Date
# 2007-04-02       717.62
# 2007-04-03       693.98
# 2007-04-04       684.05
# 2007-04-05       687.89
# 2007-04-09       718.71
# ...                 ...
# 2020-03-23       174.10
# 2020-03-24       170.65
# 2020-03-25       175.10
# 2020-03-26       185.80
# 2020-03-27       185.05
#
# [3218 rows x 1 columns]

# %%
df_merged_NIFTYAuto.set_index('Date', inplace=True)
NewNIFTYAuto = df_merged_NIFTYAuto[['Close']]
NewNIFTYAuto = NewNIFTYAuto.rename(columns={"Close":"NiftyAuto"})
NewNIFTYAuto
# Out:
#             NiftyAuto
# Date
# 2004-03-31    1005.92
# 2004-04-01    1030.55
# 2004-04-02    1032.65
# 2004-04-05    1047.45
# 2004-04-06    1036.69
# ...               ...
# 2020-03-20    5370.15
# 2020-03-23    4626.50
# 2020-03-24    4693.35
# 2020-03-25    4936.15
# 2020-03-26    5061.30
#
# [3971 rows x 1 columns]

# %%
df_merged_NIFTYFS.set_index('Date', inplace=True)
NewNIFTYFS = df_merged_NIFTYFS[['Close']]
NewNIFTYFS = NewNIFTYFS.rename(columns={"Close":"NiftyFS"})
NewNIFTYFS
# Out:
#             NiftyFS
# Date
# 2004-03-31  1040.82
# 2004-04-01  1063.98
# 2004-04-02  1078.00
# 2004-04-05  1066.30
# 2004-04-06  1069.62
# ...             ...
# 2020-03-20  9871.95
# 2020-03-23  8298.50
# 2020-03-24  8418.70
# 2020-03-25  9203.30
# 2020-03-26  9698.55
#
# [3971 rows x 1 columns]

# %%
df_merged_NIFTYHealth.set_index('Date', inplace=True)
NewNIFTYHealth = df_merged_NIFTYHealth[['Close']]
NewNIFTYHealth = NewNIFTYHealth.rename(columns={"Close":"NiftyHealth"})
NewNIFTYHealth
# Out:
#             NiftyHealth
# Date
# 2005-04-01      1000.00
# 2005-04-04      1011.35
# 2005-04-05       998.85
# 2005-04-06       998.86
# 2005-04-07       991.10
# ...                 ...
# 2020-03-23      4018.85
# 2020-03-24      4107.06
# 2020-03-25      4152.13
# 2020-03-26      4201.71
# 2020-03-27      4209.01
#
# [3718 rows x 1 columns]

# %%
df_merged_NIFTYMedia.set_index('Date', inplace=True)
NewNIFTYMedia = df_merged_NIFTYMedia[['Close']]
NewNIFTYMedia = NewNIFTYMedia.rename(columns={"Close":"NiftyMedia"})
NewNIFTYMedia
# Out:
#             NiftyMedia
# Date
# 2006-04-03     1379.10
# 2006-04-04     1403.89
# 2006-04-05     1406.02
# 2006-04-07     1396.43
# 2006-04-10     1383.35
# ...                ...
# 2020-03-23     1015.40
# 2020-03-24     1031.70
# 2020-03-25     1055.45
# 2020-03-26     1067.50
# 2020-03-27     1055.40
#
# [3467 rows x 1 columns]

# %%
df_merged_NIFTYPSUB.set_index('Date', inplace=True)
NewNIFTYPSUB = df_merged_NIFTYPSUB[['Close']]
NewNIFTYPSUB = NewNIFTYPSUB.rename(columns={"Close":"NiftyPSUB"})
NewNIFTYPSUB
# Out:
#             NiftyPSUB
# Date
# 2004-03-31    1135.52
# 2004-04-01    1160.99
# 2004-04-02    1180.17
# 2004-04-05    1169.73
# 2004-04-06    1183.90
# ...               ...
# 2020-03-20    1463.45
# 2020-03-23    1277.75
# 2020-03-24    1305.35
# 2020-03-25    1327.55
# 2020-03-26    1335.15
#
# [3960 rows x 1 columns]

# %%
df_merged_NIFTYPubB.set_index('Date', inplace=True)
NewNIFTYPubB = df_merged_NIFTYPubB[['Close']]
NewNIFTYPubB = NewNIFTYPubB.rename(columns={"Close":"NiftyPubB"})
NewNIFTYPubB
# Out:
#             NiftyPubB
# Date
# 2005-04-01    1000.00
# 2005-04-04    1004.92
# 2005-04-05    1003.12
# 2005-04-06    1009.06
# 2005-04-07    1006.74
# ...               ...
# 2020-03-23    8974.30
# 2020-03-24    9050.50
# 2020-03-25    9775.85
# 2020-03-26   10556.20
# 2020-03-27   10738.15
#
# [3718 rows x 1 columns]

# %%
df_merged_NIFTYGsec.set_index('Date', inplace=True)
NewNIFTYGsec = df_merged_NIFTYGsec[['Close']]
NewNIFTYGsec = NewNIFTYGsec.rename(columns={"Close":"NiftyGsec"})
NewNIFTYGsec
# Out:
#             NiftyGsec
# Date
# 2011-01-03    1000.00
# 2011-01-04     999.07
# 2011-01-05     999.79
# 2011-01-06     995.69
# 2011-01-07     992.69
# ...               ...
# 2021-05-31    2311.32
# 2021-06-01    2310.67
# 2021-06-02    2312.67
# 2021-06-03    2314.38
# 2021-06-04    2312.51
#
# [3208 rows x 1 columns]

# %%
Indices = pd.merge(NewNIFTY50, NewNIFTY500, on='Date')
Indices1 = pd.merge(Indices, NewNIFTYBANK, on='Date')
Indices2 = pd.merge(Indices1, NewNIFTYFMCG, on='Date')
Indices3 = pd.merge(Indices2, NewNIFTYIT, on='Date')
Indices4 = pd.merge(Indices3, NewNIFTYAuto, on='Date')
Indices5 = pd.merge(Indices4, NewNIFTYFS, on='Date')
Indices6 = pd.merge(Indices5, NewNIFTYPharma, on='Date')
Indices7 = pd.merge(Indices6, NewNIFTYHealth, on='Date')
Indices8 = pd.merge(Indices7, NewNIFTYMedia, on='Date')
Indices9 = pd.merge(Indices8, NewNIFTYPSUB, on='Date')
Indices10 = pd.merge(Indices9, NewNIFTYPubB, on='Date')
Indices11 = pd.merge(Indices10, NewNIFTYRealty, on='Date')
Indices11
# Out:
#             Nifty50  Nifty500  NiftyBANK  NiftyFMCG   NiftyIT  NiftyAuto  \
# Date
# 2007-04-02  3633.60   3008.75    4959.65    4572.85   4940.45    1849.15
# 2007-04-03  3690.65   3046.65    4995.15    4637.95   5028.35    1865.64
# 2007-04-04  3733.25   3082.65    5031.75    4618.58   5085.45    1853.64
# 2007-04-05  3752.00   3100.85    5129.20    4646.93   5088.40    1858.42
# 2007-04-09  3843.50   3172.55    5323.80    4772.44   5193.95    1892.85
# ...             ...       ...        ...        ...       ...        ...
# 2020-03-20  8745.45   7160.10   20317.60   25931.60  12363.40    5370.15
# 2020-03-23  7610.25   6243.00   16917.65   23184.05  11179.60    4626.50
# 2020-03-24  7801.05   6365.45   17107.30   23935.30  11865.05    4693.35
# 2020-03-25  8317.85   6724.00   18481.05   24471.70  12233.35    4936.15
# 2020-03-26  8641.45   6993.85   19613.90   25680.10  12535.60    5061.30
#
#             NiftyFS  NiftyPharma  NiftyHealth  NiftyMedia  NiftyPSUB  \
# Date
# ...

# %%
plt.figure(figsize=(14, 7))
for c in Indices11.columns.values:
    plt.plot(Indices11.index, Indices11[c], lw=3, alpha=0.8,label=c)
plt.legend(loc='upper left', fontsize=12)
plt.ylabel('price in $')
# Out:
# Text(0, 0.5, 'price in $')

# %%
returns = Indices11.pct_change()

plt.figure(figsize=(14, 7))
for c in returns.columns.values:
    plt.plot(returns.index, returns[c], lw=3, alpha=0.8,label=c)
plt.legend(loc='upper right', fontsize=12)
plt.ylabel('daily returns')
# Out:
# Text(0, 0.5, 'daily returns')

# %%
def portfolio_annualised_performance(weights, mean_returns, cov_matrix):
    returns = np.sum(mean_returns*weights ) *252
    std = np.sqrt(np.dot(weights.T, np.dot(cov_matrix, weights))) * np.sqrt(252)
    return std, returns

# %%
def random_portfolios(num_portfolios, mean_returns, cov_matrix, risk_free_rate):
    results = np.zeros((3,num_portfolios))
    weights_record = []
    for i in range(num_portfolios):
        weights = np.random.random(13)
        weights /= np.sum(weights)
        weights_record.append(weights)
        portfolio_std_dev, portfolio_return = portfolio_annualised_performance(weights, mean_returns, cov_matrix)
        results[0,i] = portfolio_std_dev
        results[1,i] = portfolio_return
        results[2,i] = (portfolio_return - risk_free_rate) / portfolio_std_dev
    return results, weights_record

# %%
returns = Indices11.pct_change()
mean_returns = returns.mean()
cov_matrix = returns.cov()
num_portfolios = 50000
risk_free_rate = 0.0178

# %%
def display_simulated_ef_with_random(mean_returns, cov_matrix, num_portfolios, risk_free_rate):
    results, weights = random_portfolios(num_portfolios,mean_returns, cov_matrix, risk_free_rate)
    
    max_sharpe_idx = np.argmax(results[2])
    sdp, rp = results[0,max_sharpe_idx], results[1,max_sharpe_idx]
    max_sharpe_allocation = pd.DataFrame(weights[max_sharpe_idx],index=Indices11.columns,columns=['allocation'])
    max_sharpe_allocation.allocation = [round(i*100,2)for i in max_sharpe_allocation.allocation]
    max_sharpe_allocation = max_sharpe_allocation.T
    
    min_vol_idx = np.argmin(results[0])
    sdp_min, rp_min = results[0,min_vol_idx], results[1,min_vol_idx]
    min_vol_allocation = pd.DataFrame(weights[min_vol_idx],index=Indices11.columns,columns=['allocation'])
    min_vol_allocation.allocation = [round(i*100,2)for i in min_vol_allocation.allocation]
    min_vol_allocation = min_vol_allocation.T
    
    print("-"*80)
    print("Maximum Sharpe Ratio Portfolio Allocation\n")
    print("Annualised Return:", round(rp,2))
    print("Annualised Volatility:", round(sdp,2))
    print("\n")
    print(max_sharpe_allocation)
    print("-"*80)
    print("Minimum Volatility Portfolio Allocation\n")
    print("Annualised Return:", round(rp_min,2))
    print("Annualised Volatility:", round(sdp_min,2))
    print("\n")
    print(min_vol_allocation)
    
    plt.figure(figsize=(10, 7))
    plt.scatter(results[0,:],results[1,:],c=results[2,:],cmap='YlGnBu', marker='o', s=10, alpha=0.3)
    plt.colorbar()
    plt.scatter(sdp,rp,marker='*',color='r',s=500, label='Maximum Sharpe ratio')
    plt.scatter(sdp_min,rp_min,marker='*',color='g',s=500, label='Minimum volatility')
    plt.title('Simulated Portfolio Optimization based on Efficient Frontier')
    plt.xlabel('annualised volatility')
    plt.ylabel('annualised returns')
    plt.xlim([0.15, 0.3])
    plt.legend(labelspacing=0.8)

# %%
display_simulated_ef_with_random(mean_returns, cov_matrix, num_portfolios, risk_free_rate)
# Out:
# --------------------------------------------------------------------------------
# Maximum Sharpe Ratio Portfolio Allocation
#
# Annualised Return: 0.14
# Annualised Volatility: 0.21
#
#
#             Nifty50  Nifty500  NiftyBANK  NiftyFMCG  NiftyIT  NiftyAuto  \
# allocation     5.49      2.53       7.11      24.58      1.8       7.98
#
#             NiftyFS  NiftyPharma  NiftyHealth  NiftyMedia  NiftyPSUB  \
# allocation    14.84         1.03        13.64        2.22       0.17
#
#             NiftyPubB  NiftyRealty
# allocation      18.42         0.19
# --------------------------------------------------------------------------------
# Minimum Volatility Portfolio Allocation
#
# Annualised Return: 0.12
# Annualised Volatility: 0.18
#
#
#             Nifty50  Nifty500  NiftyBANK  NiftyFMCG  NiftyIT  NiftyAuto  \
# allocation     6.33      0.09       3.14      21.24    16.88       4.14
#
#             NiftyFS  NiftyPharma  NiftyHealth  NiftyMedia  NiftyPSUB  \
# ...

# %%
def neg_sharpe_ratio(weights, mean_returns, cov_matrix, risk_free_rate):
    p_var, p_ret = portfolio_annualised_performance(weights, mean_returns, cov_matrix)
    return -(p_ret - risk_free_rate) / p_var

def max_sharpe_ratio(mean_returns, cov_matrix, risk_free_rate):
    num_assets = len(mean_returns)
    args = (mean_returns, cov_matrix, risk_free_rate)
    constraints = ({'type': 'eq', 'fun': lambda x: np.sum(x) - 1})
    bound = (0.0,1.0)
    bounds = tuple(bound for asset in range(num_assets))
    result = sco.minimize(neg_sharpe_ratio, num_assets*[1./num_assets,], args=args,
                        method='SLSQP', bounds=bounds, constraints=constraints)
    return result

# %%
def portfolio_volatility(weights, mean_returns, cov_matrix):
    return portfolio_annualised_performance(weights, mean_returns, cov_matrix)[0]

def min_variance(mean_returns, cov_matrix):
    num_assets = len(mean_returns)
    args = (mean_returns, cov_matrix)
    constraints = ({'type': 'eq', 'fun': lambda x: np.sum(x) - 1})
    bound = (0.0,1.0)
    bounds = tuple(bound for asset in range(num_assets))

    result = sco.minimize(portfolio_volatility, num_assets*[1./num_assets,], args=args,
                        method='SLSQP', bounds=bounds, constraints=constraints)

    return result

# %%
def efficient_return(mean_returns, cov_matrix, target):
    num_assets = len(mean_returns)
    args = (mean_returns, cov_matrix)

    def portfolio_return(weights):
        return portfolio_annualised_performance(weights, mean_returns, cov_matrix)[1]

    constraints = ({'type': 'eq', 'fun': lambda x: portfolio_return(x) - target},
                   {'type': 'eq', 'fun': lambda x: np.sum(x) - 1})
    bounds = tuple((0,1) for asset in range(num_assets))
    result = sco.minimize(portfolio_volatility, num_assets*[1./num_assets,], args=args, method='SLSQP', bounds=bounds, constraints=constraints)
    return result


def efficient_frontier(mean_returns, cov_matrix, returns_range):
    efficients = []
    for ret in returns_range:
        efficients.append(efficient_return(mean_returns, cov_matrix, ret))
    return efficients

# %%
import scipy.optimize as sco

# %%
def display_calculated_ef_with_random(mean_returns, cov_matrix, num_portfolios, risk_free_rate):
    results, _ = random_portfolios(num_portfolios,mean_returns, cov_matrix, risk_free_rate)
    
    max_sharpe = max_sharpe_ratio(mean_returns, cov_matrix, risk_free_rate)
    sdp, rp = portfolio_annualised_performance(max_sharpe['x'], mean_returns, cov_matrix)
    max_sharpe_allocation = pd.DataFrame(max_sharpe.x,index=Indices11.columns,columns=['allocation'])
    max_sharpe_allocation.allocation = [round(i*100,2)for i in max_sharpe_allocation.allocation]
    max_sharpe_allocation = max_sharpe_allocation.T
    max_sharpe_allocation

    min_vol = min_variance(mean_returns, cov_matrix)
    sdp_min, rp_min = portfolio_annualised_performance(min_vol['x'], mean_returns, cov_matrix)
    min_vol_allocation = pd.DataFrame(min_vol.x,index=Indices11.columns,columns=['allocation'])
    min_vol_allocation.allocation = [round(i*100,2)for i in min_vol_allocation.allocation]
    min_vol_allocation = min_vol_allocation.T
    
    print("-"*80)
    print("Maximum Sharpe Ratio Portfolio Allocation\n")
    print("Annualised Return:", round(rp,2))
    print("Annualised Volatility:", round(sdp,2))
    print("\n")
    print(max_sharpe_allocation)
    print("-"*80)
    print("Minimum Volatility Portfolio Allocation\n")
    print("Annualised Return:", round(rp_min,2))
    print("Annualised Volatility:", round(sdp_min,2))
    print("\n")
    print(min_vol_allocation)
    
    plt.figure(figsize=(10, 7))
    plt.scatter(results[0,:],results[1,:],c=results[2,:],cmap='YlGnBu', marker='o', s=10, alpha=0.3)
    plt.colorbar()
    plt.scatter(sdp,rp,marker='*',color='r',s=500, label='Maximum Sharpe ratio')
    plt.scatter(sdp_min,rp_min,marker='*',color='g',s=500, label='Minimum volatility')

    target = np.linspace(rp_min, 0.32, 50)
    efficient_portfolios = efficient_frontier(mean_returns, cov_matrix, target)
    plt.plot([p['fun'] for p in efficient_portfolios], target, linestyle='-.', color='black', label='efficient frontier')
    plt.title('Calculated Portfolio Optimization based on Efficient Frontier')
    plt.xlabel('annualised volatility')
    plt.ylabel('annualised returns')
    plt.xlim([0.15, 0.3])
    plt.ylim([-0.05, 0.2])
    plt.legend(labelspacing=0.8)

# %%
display_calculated_ef_with_random(mean_returns, cov_matrix, num_portfolios, risk_free_rate)
# Out:
# --------------------------------------------------------------------------------
# Maximum Sharpe Ratio Portfolio Allocation
#
# Annualised Return: 0.16
# Annualised Volatility: 0.19
#
#
#             Nifty50  Nifty500  NiftyBANK  NiftyFMCG  NiftyIT  NiftyAuto  \
# allocation      0.0       0.0        0.0      77.93      0.0        0.0
#
#             NiftyFS  NiftyPharma  NiftyHealth  NiftyMedia  NiftyPSUB  \
# allocation      0.0          0.0          6.7         0.0        0.0
#
#             NiftyPubB  NiftyRealty
# allocation      15.37          0.0
# --------------------------------------------------------------------------------
# Minimum Volatility Portfolio Allocation
#
# Annualised Return: 0.12
# Annualised Volatility: 0.17
#
#
#             Nifty50  Nifty500  NiftyBANK  NiftyFMCG  NiftyIT  NiftyAuto  \
# allocation      0.0       0.0        0.0      36.94    13.22       4.52
#
#             NiftyFS  NiftyPharma  NiftyHealth  NiftyMedia  NiftyPSUB  \
# ...

# %%
def display_ef_with_selected(mean_returns, cov_matrix, risk_free_rate):
    max_sharpe = max_sharpe_ratio(mean_returns, cov_matrix, risk_free_rate)
    sdp, rp = portfolio_annualised_performance(max_sharpe['x'], mean_returns, cov_matrix)
    max_sharpe_allocation = pd.DataFrame(max_sharpe.x,index=Indices11.columns,columns=['allocation'])
    max_sharpe_allocation.allocation = [round(i*100,2)for i in max_sharpe_allocation.allocation]
    max_sharpe_allocation = max_sharpe_allocation.T
    max_sharpe_allocation

    min_vol = min_variance(mean_returns, cov_matrix)
    sdp_min, rp_min = portfolio_annualised_performance(min_vol['x'], mean_returns, cov_matrix)
    min_vol_allocation = pd.DataFrame(min_vol.x,index=Indices11.columns,columns=['allocation'])
    min_vol_allocation.allocation = [round(i*100,2)for i in min_vol_allocation.allocation]
    min_vol_allocation = min_vol_allocation.T
    
    an_vol = np.std(returns) * np.sqrt(252)
    an_rt = mean_returns * 252
    
    print("-"*80)
    print("Maximum Sharpe Ratio Portfolio Allocation\n")
    print("Annualised Return:", round(rp,2))
    print("Annualised Volatility:", round(sdp,2))
    print("\n")
    print(max_sharpe_allocation)
    print("-"*80)
    print("Minimum Volatility Portfolio Allocation\n")
    print("Annualised Return:", round(rp_min,2))
    print("Annualised Volatility:", round(sdp_min,2))
    print("\n")
    print(min_vol_allocation)
    print("-"*80)
    print("Individual Stock Returns and Volatility\n")
    for i, txt in enumerate(Indices11.columns):
        print(txt,":","annuaised return",round(an_rt[i],2),", annualised volatility:",round(an_vol[i],2))
    print("-"*80)
    
    fig, ax = plt.subplots(figsize=(10, 7))
    ax.scatter(an_vol,an_rt,marker='o',s=200)

    for i, txt in enumerate(Indices11.columns):
        ax.annotate(txt, (an_vol[i],an_rt[i]), xytext=(10,0), textcoords='offset points')
    ax.scatter(sdp,rp,marker='*',color='r',s=500, label='Maximum Sharpe ratio')
    ax.scatter(sdp_min,rp_min,marker='*',color='g',s=500, label='Minimum volatility')

    target = np.linspace(rp_min, 0.34, 50)
    efficient_portfolios = efficient_frontier(mean_returns, cov_matrix, target)
    ax.plot([p['fun'] for p in efficient_portfolios], target, linestyle='-.', color='black', label='efficient frontier')
    ax.set_title('Portfolio Optimization with Individual Stocks')
    ax.set_xlabel('annualised volatility')
    ax.set_ylabel('annualised returns')
    plt.xlim([0.15, 0.3])
    plt.ylim([-0.05, 0.2])
    ax.legend(labelspacing=0.8)

# %%
display_ef_with_selected(mean_returns, cov_matrix, risk_free_rate)
# Out:
# --------------------------------------------------------------------------------
# Maximum Sharpe Ratio Portfolio Allocation
#
# Annualised Return: 0.16
# Annualised Volatility: 0.19
#
#
#             Nifty50  Nifty500  NiftyBANK  NiftyFMCG  NiftyIT  NiftyAuto  \
# allocation      0.0       0.0        0.0      77.93      0.0        0.0
#
#             NiftyFS  NiftyPharma  NiftyHealth  NiftyMedia  NiftyPSUB  \
# allocation      0.0          0.0          6.7         0.0        0.0
#
#             NiftyPubB  NiftyRealty
# allocation      15.37          0.0
# --------------------------------------------------------------------------------
# Minimum Volatility Portfolio Allocation
#
# Annualised Return: 0.12
# Annualised Volatility: 0.17
#
#
#             Nifty50  Nifty500  NiftyBANK  NiftyFMCG  NiftyIT  NiftyAuto  \
# allocation      0.0       0.0        0.0      36.94    13.22       4.52
#
#             NiftyFS  NiftyPharma  NiftyHealth  NiftyMedia  NiftyPSUB  \
# ...
